# %%
import tensorflow as tf
print('Tensorflow Version:{}'.format(tf.__version__))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 这里%matplotlib inline的作用是之后使用matplot.pyplot绘制图像的时候不用调用plt.show()也可以显示图片

# %%
data=pd.read_csv('./dataset/Income1.csv')
data
# Out:
#     Unnamed: 0  Education     Income
# 0            1  10.000000  26.658839
# 1            2  10.401338  27.306435
# 2            3  10.842809  22.132410
# 3            4  11.244147  21.169841
# 4            5  11.645485  15.192634
# 5            6  12.086957  26.398951
# 6            7  12.488294  17.435307
# 7            8  12.889632  25.507885
# 8            9  13.290970  36.884595
# 9           10  13.732441  39.666109
# 10          11  14.133779  34.396281
# 11          12  14.535117  41.497994
# 12          13  14.976589  44.981575
# 13          14  15.377926  47.039595
# 14          15  15.779264  48.252578
# 15          16  16.220736  57.034251
# 16          17  16.622074  51.490919
# 17          18  17.023411  61.336621
# 18          19  17.464883  57.581988
# 19          20  17.866221  68.553714
# 20          21  18.267559  64.310925
# 21          22  18.709030  68.959009
# 22          23  19.110368  74.614639
# 23          24  19.511706  71.867195
# ...

# %% [markdown]
# 这里data=pd.read_csv()，Read a comma-separated values (csv) file into DataFrame.所以data是一个dataframe的数据结构，dataframe:Two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). Arithmetic operations align on both row and column labels. Can be thought of as a dict-like container for Series objects. The primary pandas data structure.

# %%
plt.scatter(data.Education,data.Income)

# %%
x=data.Education
y=data.Income

# %% [markdown]
# 这里利用datafrme生成series数据类型，series:One-dimensional ndarray with axis labels (including time series).

# %%
model=tf.keras.Sequential()

# %% [markdown]
# tf.keras.sequential()序列模型，下面就在model里面加入具体的层

# %%
model.add(tf.keras.layers.Dense(1,input_shape=(1,)))

# %% [markdown]
# dense()，第一个参数是输出的维度，因为是预测收入，所以输出就是向量（1维），输入的维度也是1

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='mse')

# %% [markdown]
# 对模型进行config，设置一个优化器和损失函数,这里优化器是adam，梯度下降，但是这里并没有设置学习率之类的具体参数，这里使用默认的学习率0.001

# %%
history=model.fit(x,y,epochs=5000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1004 12:34:29.313049 16656 training.py:510] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.series.Series'>, <class 'NoneType'>
# Train on 30 samples
# Epoch 1/5000
# 30/30 [==============================] - 1s 46ms/sample - loss: 2666.5588
# Epoch 2/5000
# 30/30 [==============================] - 0s 67us/sample - loss: 2664.8042
# Epoch 3/5000
# 30/30 [==============================] - 0s 67us/sample - loss: 2663.0500
# Epoch 4/5000
# 30/30 [==============================] - 0s 32us/sample - loss: 2661.2964
# Epoch 5/5000
# 30/30 [==============================] - 0s 67us/sample - loss: 2659.5437
# Epoch 6/5000
# 30/30 [==============================] - 0s 67us/sample - loss: 2657.7917
# Epoch 7/5000
# 30/30 [==============================] - 0s 34us/sample - loss: 2656.0400
# Epoch 8/5000
# ...

# %% [markdown]
# 训练模型

# %%
model.predict(x)
# Out:
# W1004 12:35:07.160289 16656 training.py:510] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.series.Series'>, <class 'NoneType'>
# array([[32.9678  ],
#        [34.188488],
#        [35.531246],
#        [36.751934],
#        [37.972622],
#        [39.31538 ],
#        [40.536068],
#        [41.756756],
#        [42.977444],
#        [44.3202  ],
#        [45.54089 ],
#        [46.761574],
#        [48.104332],
#        [49.32502 ],
#        [50.545708],
#        [51.888466],
#        [53.109154],
#        [54.329838],
#        [55.6726  ],
#        [56.893284],
#        [58.113976],
#        [59.45673 ],
#        [60.67742 ],
#        [61.898106],
#        [63.118797],
#        [64.46155 ],
#        [65.68224 ],
#        [66.90293 ],
#        [68.24568 ],
#        [69.46637 ]], dtype=float32)

# %%
model.predict(pd.Series([20]))
# Out:
# W1004 12:35:41.760356 16656 training.py:510] Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.series.Series'>, <class 'NoneType'>
# array([[63.383278]], dtype=float32)
